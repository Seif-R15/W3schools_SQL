# %%
import pandas as pd
import numpy as np

# %%
categories = pd.read_csv('categories.csv')
categories
# Out:
#    CategoryID    CategoryName  \
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           5  Grains/Cereals
# 5           6    Meat/Poultry
# 6           7         Produce
# 7           8         Seafood
#
#                                          Description Unnamed: 3 Unnamed: 4  \
# 0  Soft drinks\coffees\ teas\ beers\ and ales cof...                   NaN
# 1  Sweet and savory sauces\relishes\spreads\and s...        NaN
# 2  Desserts\ candies\ and sweet breads relishes\c...        NaN        NaN
# 3                                            Cheeses        NaN        NaN
# 4        Breads\crackers\ pasta\and cereal crackers\                   NaN
# 5                                     Prepared meats        NaN        NaN
# 6                          Dried fruit and bean curd        NaN        NaN
# 7                                   Seaweed and fish        NaN        NaN
#
# ...

# %%
categories['Unnamed: 7'].unique()
# Out:
# array([nan, ' '], dtype=object)

# %%
categories['Description'].value_counts()
# Out:
# Soft drinks\coffees\ teas\ beers\ and ales coffees\        1
# Sweet and savory sauces\relishes\spreads\and seasonings    1
# Desserts\ candies\ and sweet breads relishes\candies\      1
# Cheeses                                                    1
# Breads\crackers\ pasta\and cereal crackers\                1
# Prepared meats                                             1
# Dried fruit and bean curd                                  1
# Seaweed and fish                                           1
# Name: Description, dtype: int64

# %%
categories.drop(['Unnamed: 3','Unnamed: 4','Unnamed: 5','Unnamed: 6','Unnamed: 7'], axis=1, inplace=True)

# %%
categories
# Out:
#    CategoryID    CategoryName  \
# 0           1       Beverages
# 1           2      Condiments
# 2           3     Confections
# 3           4  Dairy Products
# 4           5  Grains/Cereals
# 5           6    Meat/Poultry
# 6           7         Produce
# 7           8         Seafood
#
#                                          Description
# 0  Soft drinks\coffees\ teas\ beers\ and ales cof...
# 1  Sweet and savory sauces\relishes\spreads\and s...
# 2  Desserts\ candies\ and sweet breads relishes\c...
# 3                                            Cheeses
# 4        Breads\crackers\ pasta\and cereal crackers\
# 5                                     Prepared meats
# 6                          Dried fruit and bean curd
# 7                                   Seaweed and fish

# %%
categories.to_csv('C:/Users/Seif/Desktop/Categories.csv', index=False)

# %%
suppliers = pd.read_csv('suppliers.csv', error_bad_lines=False)
suppliers
# Out:
# C:\Users\Seif\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# b'Skipping line 8: expected 8 fields, saw 9\nSkipping line 9: expected 8 fields, saw 9\nSkipping line 15: expected 8 fields, saw 9\nSkipping line 19: expected 8 fields, saw 9\nSkipping line 21: expected 8 fields, saw 9\nSkipping line 25: expected 8 fields, saw 9\nSkipping line 27: expected 8 fields, saw 9\nSkipping line 28: expected 8 fields, saw 9\nSkipping line 29: expected 8 fields, saw 9\n'
#     SupplierID                            SupplierName  \
# 0            1                           Exotic Liquid
# 1            2              New Orleans Cajun Delights
# 2            3               Grandma Kelly's Homestead
# 3            4                           Tokyo Traders
# 4            5      Cooperativa de Quesos 'Las Cabras'
# ...

# %%
suppliers.to_csv('C:/Users/Seif/Desktop/suppliers.csv', index=False)

# %%
customers = pd.read_csv('customers.csv',error_bad_lines=False)
customers
# Out:
# C:\Users\Seif\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3331: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %%
customers.to_csv('C:/Users/Seif/Desktop/customers.csv', index=False)

# %%
employees = pd.read_csv('employees.csv',error_bad_lines=False)
employees
# Out:
# b'Skipping line 3: expected 6 fields, saw 9\nSkipping line 6: expected 6 fields, saw 10\nSkipping line 7: expected 6 fields, saw 10\nSkipping line 8: expected 6 fields, saw 7\n'
#    EmployeeID FirstName   LastName   BirthDate        Photo  \
# 0           1     Nancy    Davolio  1968-12-08   EmpID1.pic
# 1           3     Janet  Leverling  1963-08-30   EmpID3.pic
# 2           4  Margaret    Peacock  1958-09-19   EmpID4.pic
# 3           8     Laura   Callahan  1958-01-09   EmpID8.pic
# 4           9      Anne  Dodsworth  1969-07-02   EmpID9.pic
# 5          10      Adam       West  1928-09-19  EmpID10.pic
#
#                                                Notes
# 0  Education includes a BA in psychology from Col...
# 1  Janet has a BS degree in chemistry from Boston...
# 2  Margaret holds a BA in English literature from...
# 3  Laura received a BA in psychology from the Uni...
# 4  Anne has a BA degree in English from St. Lawre...
# ...

# %%
employees.to_csv('C:/Users/Seif/Desktop/employees.csv', index=False)

# %%
order_details = pd.read_csv('order_details.csv')
order_details
# Out:
#      OrderDetailID  OrderID  ProductID  Quantity
# 0                1    10248         11        12
# 1                2    10248         42        10
# 2                3    10248         72         5
# 3                4    10249         14         9
# 4                5    10249         51        40
# ..             ...      ...        ...       ...
# 513            514    10442         11        30
# 514            515    10442         54        80
# 515            516    10442         66        60
# 516            517    10443         11         6
# 517            518    10443         28        12
#
# [518 rows x 4 columns]

# %%
order_details.to_csv('C:/Users/Seif/Desktop/order_details.csv', index=False)

# %%
orders =  pd.read_csv('orders.csv')
orders
# Out:
#      OrderID  CustomerID  EmployeeID   ShipperID  OrderDate
# 0      10248          90           5  1996-07-04          3
# 1      10249          81           6  1996-07-05          1
# 2      10250          34           4  1996-07-08          2
# 3      10251          84           3  1996-07-08          1
# 4      10252          76           4  1996-07-09          2
# ..       ...         ...         ...         ...        ...
# 191    10439          51           6  1997-02-07          3
# 192    10440          71           4  1997-02-10          2
# 193    10441          55           3  1997-02-10          2
# 194    10442          20           3  1997-02-11          2
# 195    10443          66           8  1997-02-12          1
#
# [196 rows x 5 columns]

# %%
orders.to_csv('C:/Users/Seif/Desktop/orders.csv', index=False)

# %%
shippers =  pd.read_csv('shippers.csv')
shippers
# Out:
#    ShipperID       ShipperName           Phone
# 0          1    Speedy Express  (503) 555-9831
# 1          2    United Package  (503) 555-3199
# 2          3  Federal Shipping  (503) 555-9931

# %%
shippers.to_csv('C:/Users/Seif/Desktop/shippers.csv', index=False)
